# %% [markdown]
# #**Stock Trading Using Deep Q-Learning**

# %% [markdown]
# ## **Problem Statement**

# %% [markdown]
# Prepare an agent by implementing Deep Q-Learning that can perform unsupervised trading in stock trade. The aim of this project is to train an agent that uses Q-learning and neural networks to predict the profit or loss by building a model and implementing it on a dataset that is available for evaluation.
#
#
# The stock trading index environment provides the agent with a set of actions:<br>
# * Buy<br>
# * Sell<br>
# * Sit
#
# This project has following sections:
# * Import libraries
# * Create a DQN agent
# * Preprocess the data
# * Train and build the model
# * Evaluate the model and agent
# <br><br>
#
# **Steps to perform**<br>
#
# In the section **create a DQN agent**, create a class called agent where:
# * Action size is defined as 3
# * Experience replay memory to deque is 1000
# * Empty list for stocks that has already been bought
# * The agent must possess the following hyperparameters:<br>
#   * gamma= 0.95<br>
#   * epsilon = 1.0<br>
#   * epsilon_final = 0.01<br>
#   * epsilon_decay = 0.995<br>
#
#
#     Note: It is advised to compare the results using different values in hyperparameters.
#
# * Neural network has 3 hidden layers
# * Action and experience replay are defined

# %% [markdown]
# ## **Solution**

# %% [markdown]
# ### **Import the libraries**

# %%
"""
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.layers import Dense
#from keras.optimizers import Adam
from tensorflow.keras.optimizers import Adam, SGD, RMSprop
import numpy as np
import random
from collections import deque
"""
#!pip install gym
import random
import gym
import numpy as np
from collections import deque
#from keras import backend as K
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import tensorflow as tf
import tensorflow.keras
#from keras.models import Sequential
from tensorflow.keras.models import load_model

# %% [markdown]
# ### **Create a DQN agent**

# %% [markdown]
# **Use the instruction below to prepare an agent**

# %%
#Action space include 3 actions: Buy, Sell, and Sit
#Setting up the experience replay memory to deque with 1000 elements inside it
#Empty list with inventory is created that contains the stocks that were already bought
#Setting up gamma to 0.95, that helps to maximize the current reward over the long-term
#Epsilon parameter determines whether to use a random action or to use the model for the action. 
#In the beginning random actions are encouraged, hence epsilon is set up to 1.0 when the model is not trained.
#And over time the epsilon is reduced to 0.01 in order to decrease the random actions and use the trained model
#We're then set the speed of decreasing epsililon in the epsilon_decay parameter

class Agent:
	def __init__(self, state_size, is_eval=False, model_name=""):
		self.state_size = state_size # normalized previous days
		self.action_size = 3 # sit, buy, sell
		self.memory = deque(maxlen=1000)
		self.inventory = []
		self.model_name = model_name
		self.is_eval = is_eval
		self.gamma = 0.95
		self.epsilon = 1.0
		self.epsilon_min = 0.01
		self.epsilon_decay = 0.995
		self.model = load_model("" + model_name) if is_eval else self._model()

#Defining our neural network:
#Define the neural network function called _model and it just takes the keyword self
#Define the model with Sequential()
#Define states i.e. the previous n days and stock prices of the days
#Defining 3 hidden layers in this network
#Changing the activation function to relu because mean-squared error is used for the loss
        
	def _model(self):
		model = Sequential()
		model.add(Dense(units=64, input_dim=self.state_size, activation="relu"))
		model.add(Dense(units=32, activation="relu"))
		model.add(Dense(units=8, activation="relu"))
		model.add(Dense(self.action_size, activation="linear"))
		model.compile(loss="mse", optimizer=Adam(lr=0.001))
		return model

	def act(self, state):
		if not self.is_eval and np.random.rand() <= self.epsilon:
			return random.randrange(self.action_size)
		options = self.model.predict(state)
		return np.argmax(options[0])

	def expReplay(self, batch_size):
		mini_batch = []
		l = len(self.memory)
		for i in range(l - batch_size + 1, l):
			mini_batch.append(self.memory[i])
		for state, action, reward, next_state, done in mini_batch:
			target = reward
			if not done:
				target = reward + self.gamma * np.amax(self.model.predict(next_state)[0])
			target_f = self.model.predict(state)
			target_f[0][action] = target
			self.model.fit(state, target_f, epochs=1, verbose=0)
		if self.epsilon > self.epsilon_min:
			self.epsilon *= self.epsilon_decay
		mini_batch = []
		l = len(self.memory)
		for i in range(l - batch_size + 1, l):
			mini_batch.append(self.memory[i])
		for state, action, reward, next_state, done in mini_batch:
			target = reward
			if not done:
				target = reward + self.gamma * np.amax(self.model.predict(next_state)[0])
			target_f = self.model.predict(state)
			target_f[0][action] = target
			self.model.fit(state, target_f, epochs=1, verbose=0)
		if self.epsilon > self.epsilon_min:
			self.epsilon *= self.epsilon_decay

# %% [markdown]
# ### **Preprocess the stock market data**

# %%
import math

# prints formatted price
def formatPrice(n):
	return ("-$" if n < 0 else "$") + "{0:.2f}".format(abs(n))

# returns the vector containing stock data from a fixed file
def getStockDataVec(key):
	vec = []
	lines = open("" + key + ".csv", "r").read().splitlines()

	for line in lines[1:]:
		vec.append(float(line.split(",")[4]))

	return vec

# returns the sigmoid
def sigmoid(x):
	return 1 / (1 + math.exp(-x))

# returns an an n-day state representation ending at time t
def getState(data, t, n):
	d = t - n + 1
	block = data[d:t + 1] if d >= 0 else -d * [data[0]] + data[0:t + 1] # pad with t0
	res = []
	for i in range(n - 1):
		res.append(sigmoid(block[i + 1] - block[i]))

	return np.array([res])

# %% [markdown]
# ### **Train and build the model**

# %%
import sys

if len(sys.argv) != 4:
	print ("Usage: python train.py [stock] [window] [episodes]")
	exit()


stock_name = input("Enter stock_name, window_size, Episode_count")
#Fill the given information when prompted: 
#Enter stock_name = GSPC_Training_Dataset
#window_size = 10
#Episode_count = 100 or it can be 10 or 20 or 30 and so on.

window_size = input()
episode_count = input()
stock_name = str(stock_name)
window_size = int(window_size)
episode_count = int(episode_count)

agent = Agent(window_size)
data = getStockDataVec(stock_name)
l = len(data) - 1
batch_size = 32

for e in range(episode_count + 1):
	print ("Episode " + str(e) + "/" + str(episode_count))
	state = getState(data, 0, window_size + 1)

	total_profit = 0
	agent.inventory = []

	for t in range(l):
		action = agent.act(state)

		# sit
		next_state = getState(data, t + 1, window_size + 1)
		reward = 0

		if action == 1: # buy
			agent.inventory.append(data[t])
			print ("Buy: " + formatPrice(data[t]))

		elif action == 2 and len(agent.inventory) > 0: # sell
			bought_price = agent.inventory.pop(0)
			reward = max(data[t] - bought_price, 0)
			total_profit += data[t] - bought_price
			print ("Sell: " + formatPrice(data[t]) + " | Profit: " + formatPrice(data[t] - bought_price))

		done = True if t == l - 1 else False
		agent.memory.append((state, action, reward, next_state, done))
		state = next_state

		if done:
			print ("--------------------------------")
			print ("Total Profit: " + formatPrice(total_profit))
			

		if len(agent.memory) > batch_size:
			agent.expReplay(batch_size)

	#if e % 10 == 0:
		agent.model.save("model_ep" + str(e))
# Out:
# Usage: python train.py [stock] [window] [episodes]
# Enter stock_name, window_size, Episode_countGSPC_Training_Dataset
# 1
# 1
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\keras\optimizer_v2\adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Episode 0/1
# Buy: $1283.27
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1347.56 | Profit: $64.29
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1333.34
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1298.35
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1295.86 | Profit: -$37.48
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1300.80 | Profit: $2.45
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1313.27
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1326.82
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1318.55 | Profit: $5.28
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1326.65 | Profit: -$0.17
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1347.97
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1342.54 | Profit: -$5.43
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1364.30
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1357.51
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1354.95 | Profit: -$9.35
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1373.73 | Profit: $16.22
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1332.53
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1314.76
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1330.31
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1318.80
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1315.92
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1301.53 | Profit: -$31.00
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1278.94
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1245.86
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1267.65
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1257.94 | Profit: -$56.82
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1241.41 | Profit: -$88.90
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1264.74 | Profit: -$54.06
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1233.42 | Profit: -$82.50
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1166.71
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1173.56 | Profit: -$105.38
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1150.53 | Profit: -$95.33
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1170.81
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1142.62
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1122.14 | Profit: -$145.51
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1117.58 | Profit: -$49.13
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1139.83
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1182.17
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $878.36
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $887.34
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $861.40
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $844.61 | Profit: -$33.75
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $855.70 | Profit: -$31.64
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $860.32 | Profit: -$1.08
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $829.85
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $822.10 | Profit: -$7.75
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $911.37
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $919.02 | Profit: $7.65
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $975.93
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $984.84
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $998.51
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $988.61 | Profit: $12.68
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $995.69 | Profit: $10.85
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $981.64 | Profit: -$16.87
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $978.80
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $988.11
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $988.61
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $981.60
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $998.68
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $996.52
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $989.28 | Profit: $10.48
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $987.49 | Profit: -$0.62
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $990.31 | Profit: $1.70
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $980.15 | Profit: -$1.45
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $982.82 | Profit: -$15.86
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $965.46 | Profit: -$31.06
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1016.42
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1018.63
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1014.81
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1039.58
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1036.30 | Profit: $19.88
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1022.82 | Profit: $4.19
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1029.03 | Profit: $14.22
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1009.38 | Profit: -$30.20
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1059.02
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1053.25
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1058.05
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1047.11 | Profit: -$11.91
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1046.57 | Profit: -$6.68
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1058.53 | Profit: $0.48
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1068.04
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1076.48 | Profit: $8.44
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1127.23
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1121.22
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1130.52
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1132.05 | Profit: $4.82
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1139.83 | Profit: $18.61
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1138.77 | Profit: $8.25
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1154.87
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1156.86
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1123.89 | Profit: -$30.98
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1106.78 | Profit: -$50.08
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# ...
# Sell: $1209.25 | Profit: -$10.18
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1174.28
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1165.36 | Profit: -$8.92
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1181.41
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1180.59
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1172.92
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1181.39 | Profit: -$0.02
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1191.14
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1181.20
# INFO:tensorflow:Assets written to: model_ep0\assets
# Buy: $1181.21
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1187.76 | Profit: $7.17
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1173.79 | Profit: $0.87
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1162.05 | Profit: -$29.09
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1142.62 | Profit: -$38.58
# INFO:tensorflow:Assets written to: model_ep0\assets
# Sell: $1145.98 | Profit: -$35.23
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# INFO:tensorflow:Assets written to: model_ep0\assets
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11588/3065986649.py in <module>
#      57
#      58                 if len(agent.memory) > batch_size:
# ---> 59                         agent.expReplay(batch_size)
#      60
#      61         #if e % 10 == 0:
#
# ~\AppData\Local\Temp/ipykernel_11588/423129146.py in expReplay(self, batch_size)
#      65                         target = reward
#      66                         if not done:
# ---> 67                                 target = reward + self.gamma * np.amax(self.model.predict(next_state)[0])
#      68                         target_f = self.model.predict(state)
#      69                         target_f[0][action] = target
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1756               stacklevel=2)
#    1757
# -> 1758       data_handler = data_adapter.get_data_handler(
#    1759           x=x,
#    1760           batch_size=batch_size,
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\keras\engine\data_adapter.py in get_data_handler(*args, **kwargs)
#    1401   if getattr(kwargs["model"], "_cluster_coordinator", None):
#    1402     return _ClusterCoordinatorDataHandler(*args, **kwargs)
# -> 1403   return DataHandler(*args, **kwargs)
#    1404
#    1405
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weight, batch_size, steps_per_epoch, initial_epoch, epochs, shuffle, class_weight, max_queue_size, workers, use_multiprocessing, model, steps_per_execution, distribute)
#    1151
#    1152     adapter_cls = select_data_adapter(x, y)
# -> 1153     self._adapter = adapter_cls(
#    1154         x,
#    1155         y,
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     323       return flat_dataset
#     324
# --> 325     indices_dataset = indices_dataset.flat_map(slice_batch_indices)
#     326
#     327     dataset = self.slice_inputs(indices_dataset, inputs)
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in flat_map(self, map_func, name)
#    2046       Dataset: A `Dataset`.
#    2047     """
# -> 2048     return FlatMapDataset(self, map_func, name=name)
#    2049
#    2050   def interleave(self,
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, input_dataset, map_func, name)
#    5547     """See `Dataset.flat_map()` for details."""
#    5548     self._input_dataset = input_dataset
# -> 5549     self._map_func = StructuredFunctionWrapper(
#    5550         map_func, self._transformation_name(), dataset=input_dataset)
#    5551     if not isinstance(self._map_func.output_structure, DatasetSpec):
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, func, transformation_name, dataset, input_classes, input_shapes, input_types, input_structure, add_to_graph, use_legacy_function, defun_kwargs)
#    4531         fn_factory = trace_tf_function(defun_kwargs)
#    4532
# -> 4533     self._function = fn_factory()
#    4534     # There is no graph to add in eager mode.
#    4535     add_to_graph &= not context.executing_eagerly()
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\eager\function.py in get_concrete_function(self, *args, **kwargs)
#    3242          or `tf.Tensor` or `tf.TensorSpec`.
#    3243     """
# -> 3244     graph_function = self._get_concrete_function_garbage_collected(
#    3245         *args, **kwargs)
#    3246     graph_function._garbage_collector.release()  # pylint: disable=protected-access
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\eager\function.py in _get_concrete_function_garbage_collected(self, *args, **kwargs)
#    3208       args, kwargs = None, None
#    3209     with self._lock:
# -> 3210       graph_function, _ = self._maybe_define_function(args, kwargs)
#    3211       seen_names = set()
#    3212       captured = object_identity.ObjectIdentitySet(
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\eager\function.py in _maybe_define_function(self, args, kwargs)
#    3555
#    3556           self._function_cache.missed.add(call_context_key)
# -> 3557           graph_function = self._create_graph_function(args, kwargs)
#    3558           self._function_cache.primary[cache_key] = graph_function
#    3559
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\eager\function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3390     arg_names = base_arg_names + missing_arg_names
#    3391     graph_function = ConcreteFunction(
# -> 3392         func_graph_module.func_graph_from_py_func(
#    3393             self._name,
#    3394             self._python_function,
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\framework\func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1141         _, original_func = tf_decorator.unwrap(python_func)
#    1142
# -> 1143       func_outputs = python_func(*func_args, **func_kwargs)
#    1144
#    1145       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in wrapped_fn(*args)
#    4508           attributes=defun_kwargs)
#    4509       def wrapped_fn(*args):  # pylint: disable=missing-docstring
# -> 4510         ret = wrapper_helper(*args)
#    4511         ret = structure.to_tensor_list(self._output_structure, ret)
#    4512         return [ops.convert_to_tensor(t) for t in ret]
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in wrapper_helper(*args)
#    4438       if not _should_unpack(nested_args):
#    4439         nested_args = (nested_args,)
# -> 4440       ret = autograph.tf_convert(self._func, ag_ctx)(*nested_args)
#    4441       if _should_pack(ret):
#    4442         ret = tuple(ret)
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\autograph\impl\api.py in wrapper(*args, **kwargs)
#     694       try:
#     695         with conversion_ctx:
# --> 696           return converted_call(f, args, kwargs, options=options)
#     697       except Exception as e:  # pylint:disable=broad-except
#     698         if hasattr(e, 'ag_error_metadata'):
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\autograph\impl\api.py in converted_call(f, args, kwargs, caller_fn_scope, options)
#     381
#     382   if not options.user_requested and conversion.is_allowlisted(f):
# --> 383     return _call_unconverted(f, args, kwargs, options)
#     384
#     385   # internal_convert_user_code is for example turned off when issuing a dynamic
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\autograph\impl\api.py in _call_unconverted(f, args, kwargs, options, update_cache)
#     462
#     463   if kwargs is not None:
# --> 464     return f(*args, **kwargs)
#     465   return f(*args)
#     466
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\keras\engine\data_adapter.py in slice_batch_indices(indices)
#     314       flat_dataset = tf.data.Dataset.from_tensor_slices(first_k_indices)
#     315       if self._partial_batch_size:
# --> 316         index_remainder = tf.data.Dataset.from_tensors(tf.slice(
#     317             indices, [num_in_full_batch], [self._partial_batch_size]))
#     318         flat_dataset = flat_dataset.concatenate(index_remainder)
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\util\dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\ops\array_ops.py in slice(input_, begin, size, name)
#    1107     A `Tensor` the same type as `input_`.
#    1108   """
# -> 1109   return gen_array_ops._slice(input_, begin, size, name=name)
#    1110
#    1111
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\ops\gen_array_ops.py in _slice(input, begin, size, name)
#    9579       pass  # Add nodes to the TensorFlow graph.
#    9580   # Add nodes to the TensorFlow graph.
# -> 9581   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#    9582         "Slice", input=input, begin=begin, size=size, name=name)
#    9583   _result = _outputs[:]
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(op_type_name, name, **keywords)
#     510                   preferred_dtype=default_dtype)
#     511           else:
# --> 512             values = ops.convert_to_tensor(
#     513                 values,
#     514                 name=input_arg.name,
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\profiler\trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1619
#    1620     if ret is None:
# -> 1621       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1622
#    1623     if ret is NotImplemented:
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     345                                          as_ref=False):
#     346   _ = as_ref
# --> 347   return constant(v, dtype=dtype, name=name)
#     348
#     349
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     269     ValueError: if called on a symbolic tensor.
#     270   """
# --> 271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     272                         allow_broadcast=True)
#     273
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     291   dtype_value = attr_value_pb2.AttrValue(type=tensor_value.tensor.dtype)
#     292   attrs = {"value": tensor_value, "dtype": dtype_value}
# --> 293   const_tensor = g._create_op_internal(  # pylint: disable=protected-access
#     294       "Const", [], [dtype_value.type], attrs=attrs, name=name).outputs[0]
#     295
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\framework\func_graph.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#     687       inp = self.capture(inp)
#     688       captured_inputs.append(inp)
# --> 689     return super(FuncGraph, self)._create_op_internal(  # pylint: disable=protected-access
#     690         op_type, captured_inputs, dtypes, input_types, name, attrs, op_def,
#     691         compute_device)
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\framework\ops.py in _create_op_internal(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_device)
#    3695     # Session.run call cannot occur between creating and mutating the op.
#    3696     with self._mutation_lock():
# -> 3697       ret = Operation(
#    3698           node_def,
#    3699           self,
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    2095       if op_def is None:
#    2096         op_def = self._graph._get_op_def(node_def.op)
# -> 2097       self._c_op = _create_c_op(self._graph, node_def, inputs,
#    2098                                 control_input_ops, op_def)
#    2099       name = compat.as_str(node_def.name)
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\util\traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# D:\Software\Anaconda3\envs\Sara\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs, op_def)
#    1907   inputs = _reconstruct_sequence_inputs(op_def, inputs, node_def.attr)
#    1908   # pylint: disable=protected-access
# -> 1909   op_desc = pywrap_tf_session.TF_NewOperation(graph._c_graph,
#    1910                                               compat.as_str(node_def.op),
#    1911                                               compat.as_str(node_def.name))
#
# KeyboardInterrupt:

# %% [markdown]
# ### **Evaluate the model and agent**

# %%
import sys
from keras.models import load_model


if len(sys.argv) != 3:
	print ("Usage: python evaluate.py [stock] [model]")
	exit()


stock_name = input("Enter Stock_name, Model_name")
model_name = input()
#Note: 
#Fill the given information when prompted: 
#Enter stock_name = GSPC_Evaluation_Dataset
#Model_name = respective model name

model = load_model("" + model_name)
window_size = model.layers[0].input.shape.as_list()[1]

agent = Agent(window_size, True, model_name)
data = getStockDataVec(stock_name)
l = len(data) - 1
batch_size = 32

state = getState(data, 0, window_size + 1)
total_profit = 0
agent.inventory = []

for t in range(l):
	action = agent.act(state)

	# sit
	next_state = getState(data, t + 1, window_size + 1)
	reward = 0

	if action == 1: # buy
		agent.inventory.append(data[t])
		print ("Buy: " + formatPrice(data[t]))

	elif action == 2 and len(agent.inventory) > 0: # sell
		bought_price = agent.inventory.pop(0)
		reward = max(data[t] - bought_price, 0)
		total_profit += data[t] - bought_price
		print ("Sell: " + formatPrice(data[t]) + " | Profit: " + formatPrice(data[t] - bought_price))

	done = True if t == l - 1 else False
	agent.memory.append((state, action, reward, next_state, done))
	state = next_state

	if done:
		print ("--------------------------------")
		print (stock_name + " Total Profit: " + formatPrice(total_profit))
# Out:
# Enter Stock_name, Model_nameGSPC_Evaluation_Dataset
# model_ep0
# --------------------------------
# GSPC_Evaluation_Dataset Total Profit: $0.00

# %% [markdown]
# **Note: Run the training section for considerable episodes so that while evaluating the model it can generate significant profit.**
